# %%
#import pandas
import pandas as pd

# %%
us_babies=pd.read_csv('us_baby_names.csv')

# %%
us_babies
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
us_babies_2014 = us_babies[us_babies['Year']==2014]

# %%
us_babies_2014
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
us_babies_2014_sorted =us_babies_2014.sort_values(['Count'],  ascending=False)

# %%
us_babies_2014_sorted
# Out:
#               Id     Name  Year Gender  Count
# 1792389  1792390     Emma  2014      F  20799
# 1792390  1792391   Olivia  2014      F  19674
# 1811456  1811457     Noah  2014      M  19144
# 1792391  1792392   Sophia  2014      F  18490
# 1811457  1811458     Liam  2014      M  18342
# ...          ...      ...   ...    ...    ...
# 1825424  1825425  Zmarion  2014      M      5
# 1825423  1825424   Ziyang  2014      M      5
# 1825422  1825423    Ziyah  2014      M      5
# 1825421  1825422    Zivon  2014      M      5
# 1825420  1825421    Zirui  2014      M      5
#
# [33044 rows x 5 columns]

# %%
top_names = us_babies_2014_sorted.iloc[:5]

# %%
top_names
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
years=us_babies['Year']
names = us_babies['Name']

# %%
years
# Out:
# 0          1880
# 1          1880
# 2          1880
# 3          1880
# 4          1880
#            ...
# 1825428    2014
# 1825429    2014
# 1825430    2014
# 1825431    2014
# 1825432    2014
# Name: Year, Length: 1825433, dtype: int64

# %%
names
# Out:
# 0               Mary
# 1               Anna
# 2               Emma
# 3          Elizabeth
# 4             Minnie
#              ...
# 1825428       Zykeem
# 1825429       Zymeer
# 1825430      Zymiere
# 1825431        Zyran
# 1825432        Zyrin
# Name: Name, Length: 1825433, dtype: object

# %%
for name in names:
    data = us_babies[us_babies['Name']==name]
    plt.plot(data['Year'], data['Count'], marker = 'o', label=name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 for name in names:
# ----> 2     data = us_babies[us_babies['Name']==name]
#       3     plt.plot(data['Year'], data['Count'], marker = 'o', label=name)
#
# File c:\Users\blagl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\blagl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...
